# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
import intertools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e237d4202701> in <module>()
# ----> 1 import intertools
#
# ModuleNotFoundError: No module named 'intertools'

# %%
import itertools

# %%
import pandas pd
# Out:
#   File "<ipython-input-4-f5924d03058b>", line 1
#     import pandas pd
#                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
import numpy as np

# %%
import statsmodels.api as sm
# Out:
# C:\Users\willi10l\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('C:\\Users\\willi10l\\Downloads\\C-2Splitter_Combined_Shutdown_Rmvd.csv')

# %%
df.head()
# Out:
#         Date_Time  LC4462_PVlevel in drumDEETH REFLUX DRUMPerc  \
# 0  7/1/2015 12:00                                    69.183536
# 1  7/1/2015 12:01                                    69.089791
# 2  7/1/2015 12:02                                    69.004900
# 3  7/1/2015 12:03                                    68.916019
# 4  7/1/2015 12:04                                    68.861485
#
#    PC4462_PVpress in drumDEETH REFLUX DRUMKG_CM2G  \
# 0                                       25.543735
# 1                                       25.541403
# 2                                       25.545714
# 3                                       25.552495
# 4                                       25.559894
#
#    FC4461_PVC2 splitter feedETHYLENE SPLITTER FEEDKG_HR  \
# 0                                        61208.43065
# 1                                        61100.86964
# 2                                        61094.28844
# 3                                        61174.13925
# ...

# %%
df.describe(inlcude=['object'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-632aed60f72d> in <module>()
# ----> 1 df.describe(inlcude=['object'])
#
# TypeError: describe() got an unexpected keyword argument 'inlcude'

# %%
df.describe(include=['object'])
# Out:
#              Date_Time
# count           970908
# unique          970908
# top     9/3/2016 21:24
# freq                 1

# %%
data = pd.read_csv('C-2Splitter_Combined_Shutdown_Rmvd.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-f5d86b0cd2be> in <module>()
# ----> 1 data = pd.read_csv('C-2Splitter_Combined_Shutdown_Rmvd.csv')
#
# ...

# %%
data = pd.read(C:\\Users\\willi10l\\Downloads\\C-2Splitter_Combined_Shutdown_Rmvd.csv)
# Out:
#   File "<ipython-input-16-b0d4792bca3d>", line 1
#     data = pd.read(C:\\Users\\willi10l\\Downloads\\C-2Splitter_Combined_Shutdown_Rmvd.csv)
#                     ^
# SyntaxError: invalid syntax

# %%
data = pd_read(C:\\Users\\willi10l\\Downloads\\C-2Splitter_Combined_Shutdown_Rmvd.csv)
# Out:
#   File "<ipython-input-17-e3bc4050c9f5>", line 1
#     data = pd_read(C:\\Users\\willi10l\\Downloads\\C-2Splitter_Combined_Shutdown_Rmvd.csv)
#                     ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv(C:\\Users\\willi10l\\Downloads\\C-2Splitter_Combined_Shutdown_Rmvd.csv)
# Out:
#   File "<ipython-input-18-e0088eb35bf7>", line 1
#     data = pd.read_csv(C:\\Users\\willi10l\\Downloads\\C-2Splitter_Combined_Shutdown_Rmvd.csv)
#                         ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('C:\\Users\\willi10l\\Downloads\\C-2Splitter_Combined_Shutdown_Rmvd.csv')

# %%
y = df.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-f3675b4fe560> in <module>()
# ----> 1 y = df.data
#
# C:\Users\willi10l\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
y = df

# %%
y = y['TI4706_PVC2 splitter bottom tempETHYLENE SPLTR BTMSDEGC'].resample('MS').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-4155128ef963> in <module>()
# ----> 1 y = y['TI4706_PVC2 splitter bottom tempETHYLENE SPLTR BTMSDEGC'].resample('MS').mean()
#
# C:\Users\willi10l\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    4582                      axis=axis, kind=kind, loffset=loffset,
#    4583                      convention=convention,
# -> 4584                      base=base, key=on, level=level)
#    4585         return _maybe_process_deprecations(r,
#    4586                                            how=how,
#
# C:\Users\willi10l\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
# ...

# %%
y = y['Date_Time'].resample('MS').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-89cc58d5cdd1> in <module>()
# ----> 1 y = y['Date_Time'].resample('MS').mean()
#
# C:\Users\willi10l\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    4582                      axis=axis, kind=kind, loffset=loffset,
#    4583                      convention=convention,
# -> 4584                      base=base, key=on, level=level)
#    4585         return _maybe_process_deprecations(r,
#    4586                                            how=how,
#
# C:\Users\willi10l\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#     961     """ create a TimeGrouper and return our resampler """
# ...

# %%
y = y['Date_Time'].resample('MS').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-89cc58d5cdd1> in <module>()
# ----> 1 y = y['Date_Time'].resample('MS').mean()
#
# C:\Users\willi10l\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    4582                      axis=axis, kind=kind, loffset=loffset,
#    4583                      convention=convention,
# -> 4584                      base=base, key=on, level=level)
#    4585         return _maybe_process_deprecations(r,
#    4586                                            how=how,
#
# C:\Users\willi10l\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#     961     """ create a TimeGrouper and return our resampler """
# ...

# %%
y.plot(figsize(15,6))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9228899b7228> in <module>()
# ----> 1 y.plot(figsize(15,6))
#
# NameError: name 'figsize' is not defined

# %%
plt.show()

# %%
y.plot(figsize=(15, 6))
plt.show()

# %%
p = d = q range(0, 2)
# Out:
#   File "<ipython-input-28-e76c9b871f6e>", line 1
#     p = d = q range(0, 2)
#                   ^
# SyntaxError: invalid syntax

# %%
pdq = list(itertools.product(p, d, q))

# %%
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b9f831913bda> in <module>()
# ----> 1 seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
#
# NameError: name 'p' is not defined

# %%
p = d = q = range(0, 2)

# %%
pdq = list(itertools.product(p, d, q))

# %%
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
warnings.fliterwarnings("ignore") #specifiy to ignore warning messages
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-0f99f9c25471> in <module>()
# ----> 1 warnings.fliterwarnings("ignore") #specifiy to ignore warning messages
#
# AttributeError: module 'warnings' has no attribute 'fliterwarnings'

# %%
warnings.filterwarnings("ignore")

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
